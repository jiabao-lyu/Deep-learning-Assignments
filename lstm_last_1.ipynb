# %%
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.utils import shuffle
np.random.seed(0)
import missingno as mg
import datetime
from pmdarima.arima import auto_arima
from datetime import datetime,timedelta

# %%
def mape(y, y_pred):
    return np.mean(np.abs((y_pred - y) / y)) * 100

# %%
df = pd.read_csv('Google_Stock_Price_Train.csv')
df.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
test = pd.read_csv('Google_Stock_Price_Test.csv')

# %%
cols = [i for i in df.columns if i != 'Date']
min_max_scaler = []
for col in cols:
    df[col] = df[col].apply(lambda x:str(x).replace(',',''))
    df[col]=df[col].astype(float)
    
    test[col] = test[col].apply(lambda x:str(x).replace(',',''))
    test[col]=test[col].astype(float)
    
    scaler_df = pd.DataFrame(df[col])
    mms = MinMaxScaler()
    mms.fit(scaler_df)
    df[col] = mms.transform(scaler_df)
    test[col] = mms.transform(pd.DataFrame(test[col]))
    min_max_scaler.append(mms)

# %%
data = df[cols].values
X=[]
y=[]
m=20
for i in range(len(df)-m):
    X.append(data[i:m+i,:])
    y.append(data[m+i,:])
test_last = test.iloc[:m,-5:]
test_x = test.iloc[:m,-5:].values
test_x = test_x.reshape(1,test_x.shape[0],test_x.shape[1])

# %%
ind = shuffle(list(range(len(X))))
train_ind = ind[:int(0.8*len(ind))]
vali_ind = ind[int(0.8*len(ind)):]
x_train,y_train = np.array([X[i] for i in train_ind]),np.array([y[i] for i in train_ind])
x_valid,y_valid = np.array([X[i] for i in vali_ind]),np.array([y[i] for i in vali_ind])

# %%
def lstm_predict(x_train,y_train,x_valid,y_valid):
    # reshape before input
    model = tf.keras.Sequential()
    # Adding the first LSTM layer and some Dropout regularisation
    # set units = 64 for input layer
    model.add(tf.keras.layers.LSTM(units=64,input_shape=(x_train.shape[1],x_train.shape[2])))
    # drop_out layer，to prevent overfit
    model.add(tf.keras.layers.Dropout(0.2))
    # # Adding a second LSTM layer and some Dropout regularisation
#     model.add(tf.keras.layers.LSTM(units=64,return_sequences=True,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.LSTM(units=64,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.LSTM(units=40, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
    # # Adding a third LSTM layer and some Dropout regularisation
#     model.add(tf.keras.layers.LSTM(units=32,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.3))
    # Adding the output layer
    # last input layer，input units=1
#     model.add(tf.keras.layers.Dense(units=64,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.Dense(units=64,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(units=y_train.shape[1],activation='linear'))
    # Compiling the RNN, choose adam optimizer 
    adam = tf.keras.optimizers.Adam(lr=0.001)
    model.compile(optimizer=adam, loss='mean_squared_error')#tf.keras.optimizers.Adam(learning_rate=0.001)
    # Fitting the RNN to the Training set
    history = model.fit(x_train, y_train, epochs=500, batch_size=64,verbose=2,validation_data=(x_valid,y_valid))
#     model.save('model.h5')
    print(model.summary())
    import matplotlib.pyplot as plt
#     #interactive images
#     loss = history.history['loss']
#     val_loss = history.history['val_loss']
#     epochs_range = range(epoch)
#     plt.plot(epochs_range, loss, label='Train Loss')
#     plt.plot(epochs_range, val_loss, label='Test Loss')
#     plt.legend(loc='upper right')
#     plt.title('Train and Val Loss')
#     plt.show()
    # train loss and validation loss plot
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('LSTM model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.show()
    return model

# %%
model = lstm_predict(x_train,y_train,x_valid,y_valid)
# Out:
# C:\Users\admin\miniconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/500
# 16/16 - 2s - loss: 0.0928 - val_loss: 0.0196
# Epoch 2/500
# 16/16 - 0s - loss: 0.0249 - val_loss: 0.0080
# Epoch 3/500
# 16/16 - 0s - loss: 0.0141 - val_loss: 0.0044
# Epoch 4/500
# 16/16 - 0s - loss: 0.0101 - val_loss: 0.0034
# Epoch 5/500
# 16/16 - 0s - loss: 0.0089 - val_loss: 0.0027
# Epoch 6/500
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0023
# Epoch 7/500
# 16/16 - 0s - loss: 0.0076 - val_loss: 0.0022
# Epoch 8/500
# 16/16 - 0s - loss: 0.0070 - val_loss: 0.0021
# Epoch 9/500
# 16/16 - 0s - loss: 0.0072 - val_loss: 0.0020
# Epoch 10/500
# 16/16 - 0s - loss: 0.0063 - val_loss: 0.0021
# Epoch 11/500
# 16/16 - 0s - loss: 0.0064 - val_loss: 0.0022
# Epoch 12/500
# 16/16 - 0s - loss: 0.0062 - val_loss: 0.0019
# Epoch 13/500
# 16/16 - 0s - loss: 0.0058 - val_loss: 0.0018
# Epoch 14/500
# 16/16 - 0s - loss: 0.0055 - val_loss: 0.0018
# Epoch 15/500
# 16/16 - 0s - loss: 0.0052 - val_loss: 0.0019
# Epoch 16/500
# 16/16 - 0s - loss: 0.0053 - val_loss: 0.0018
# Epoch 17/500
# 16/16 - 0s - loss: 0.0052 - val_loss: 0.0018
# Epoch 18/500
# 16/16 - 0s - loss: 0.0051 - val_loss: 0.0016
# Epoch 19/500
# 16/16 - 0s - loss: 0.0050 - val_loss: 0.0016
# Epoch 20/500
# 16/16 - 0s - loss: 0.0048 - val_loss: 0.0016
# Epoch 21/500
# 16/16 - 0s - loss: 0.0050 - val_loss: 0.0016
# Epoch 22/500
# 16/16 - 0s - loss: 0.0048 - val_loss: 0.0016
# Epoch 23/500
# 16/16 - 0s - loss: 0.0047 - val_loss: 0.0015
# Epoch 24/500
# 16/16 - 0s - loss: 0.0044 - val_loss: 0.0015
# Epoch 25/500
# 16/16 - 0s - loss: 0.0045 - val_loss: 0.0016
# Epoch 26/500
# 16/16 - 0s - loss: 0.0044 - val_loss: 0.0015
# Epoch 27/500
# 16/16 - 0s - loss: 0.0043 - val_loss: 0.0014
# Epoch 28/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0014
# Epoch 29/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0015
# Epoch 30/500
# 16/16 - 0s - loss: 0.0044 - val_loss: 0.0013
# Epoch 31/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0013
# Epoch 32/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0013
# Epoch 33/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0014
# Epoch 34/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0013
# Epoch 35/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0015
# Epoch 36/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0013
# Epoch 37/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0013
# Epoch 38/500
# 16/16 - 0s - loss: 0.0039 - val_loss: 0.0015
# Epoch 39/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0012
# Epoch 40/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0012
# Epoch 41/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0012
# Epoch 42/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0012
# Epoch 43/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0012
# Epoch 44/500
# 16/16 - 0s - loss: 0.0035 - val_loss: 0.0012
# Epoch 45/500
# 16/16 - 0s - loss: 0.0035 - val_loss: 0.0012
# Epoch 46/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0012
# Epoch 47/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0011
# Epoch 48/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 49/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 50/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0012
# Epoch 51/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0011
# Epoch 52/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0012
# Epoch 53/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0011
# Epoch 54/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0011
# Epoch 55/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 56/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0013
# Epoch 57/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0012
# Epoch 58/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0012
# Epoch 59/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 60/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0010
# Epoch 61/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0011
# Epoch 62/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 63/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.9844e-04
# Epoch 64/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0010
# Epoch 65/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 9.7392e-04
# Epoch 66/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.8513e-04
# Epoch 67/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 68/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.7251e-04
# Epoch 69/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 70/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.8246e-04
# Epoch 71/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 0.0010
# Epoch 72/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0011
# Epoch 73/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.4585e-04
# Epoch 74/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.3561e-04
# Epoch 75/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.8135e-04
# Epoch 76/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 0.0011
# Epoch 77/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 78/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.4042e-04
# Epoch 79/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.5847e-04
# Epoch 80/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.6847e-04
# Epoch 81/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.1644e-04
# Epoch 82/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.8855e-04
# Epoch 83/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.1782e-04
# Epoch 84/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 8.9804e-04
# Epoch 85/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.1545e-04
# Epoch 86/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.3515e-04
# Epoch 87/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 0.0010
# Epoch 88/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.6615e-04
# Epoch 89/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.8900e-04
# Epoch 90/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.2273e-04
# Epoch 91/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.8106e-04
# Epoch 92/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.4749e-04
# Epoch 93/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.8146e-04
# Epoch 94/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.6416e-04
# Epoch 95/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.1706e-04
# Epoch 96/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.5866e-04
# Epoch 97/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.6848e-04
# Epoch 98/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.4967e-04
# Epoch 99/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.7013e-04
# Epoch 100/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.3592e-04
# Epoch 101/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.3952e-04
# Epoch 102/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.8186e-04
# Epoch 103/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.7473e-04
# Epoch 104/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.6160e-04
# Epoch 105/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.7419e-04
# Epoch 106/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.7495e-04
# Epoch 107/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.3244e-04
# Epoch 108/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.2397e-04
# Epoch 109/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.2088e-04
# Epoch 110/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.6266e-04
# Epoch 111/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.9418e-04
# Epoch 112/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.6650e-04
# Epoch 113/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.9966e-04
# Epoch 114/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.3587e-04
# Epoch 115/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.8283e-04
# Epoch 116/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9997e-04
# Epoch 117/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.1839e-04
# Epoch 118/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.9484e-04
# Epoch 119/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9619e-04
# Epoch 120/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.1988e-04
# Epoch 121/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9538e-04
# Epoch 122/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7771e-04
# Epoch 123/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.0634e-04
# Epoch 124/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.1342e-04
# Epoch 125/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6818e-04
# Epoch 126/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5674e-04
# Epoch 127/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.4992e-04
# Epoch 128/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7055e-04
# Epoch 129/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.4726e-04
# Epoch 130/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.0236e-04
# Epoch 131/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5966e-04
# Epoch 132/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.5485e-04
# Epoch 133/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.1098e-04
# Epoch 134/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7456e-04
# Epoch 135/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.4247e-04
# Epoch 136/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.6166e-04
# Epoch 137/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.3767e-04
# Epoch 138/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.3122e-04
# Epoch 139/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.6646e-04
# Epoch 140/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 8.0714e-04
# Epoch 141/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.3175e-04
# Epoch 142/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.4608e-04
# Epoch 143/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.8452e-04
# Epoch 144/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.6017e-04
# Epoch 145/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.1506e-04
# Epoch 146/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.6540e-04
# Epoch 147/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.4607e-04
# Epoch 148/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7
500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9098e-04
# Epoch 349/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1306e-04
# Epoch 350/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0321e-04
# Epoch 351/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9089e-04
# Epoch 352/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1995e-04
# Epoch 353/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9325e-04
# Epoch 354/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 6.0413e-04
# Epoch 355/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9828e-04
# Epoch 356/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.9548e-04
# Epoch 357/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8274e-04
# Epoch 358/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.9228e-04
# Epoch 359/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.8801e-04
# Epoch 360/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 6.0307e-04
# Epoch 361/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 6.0215e-04
# Epoch 362/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9813e-04
# Epoch 363/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.2606e-04
# Epoch 364/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9787e-04
# Epoch 365/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.2042e-04
# Epoch 366/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.5145e-04
# Epoch 367/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0437e-04
# Epoch 368/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.2569e-04
# Epoch 369/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8596e-04
# Epoch 370/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.8123e-04
# Epoch 371/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8891e-04
# Epoch 372/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1282e-04
# Epoch 373/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.9143e-04
# Epoch 374/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.8985e-04
# Epoch 375/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9451e-04
# Epoch 376/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8026e-04
# Epoch 377/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8293e-04
# Epoch 378/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7660e-04
# Epoch 379/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9148e-04
# Epoch 380/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.3830e-04
# Epoch 381/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.5203e-04
# Epoch 382/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9234e-04
# Epoch 383/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8539e-04
# Epoch 384/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.7846e-04
# Epoch 385/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1604e-04
# Epoch 386/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.3370e-04
# Epoch 387/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7559e-04
# Epoch 388/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8705e-04
# Epoch 389/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7620e-04
# Epoch 390/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.8209e-04
# Epoch 391/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 6.0205e-04
# Epoch 392/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.7561e-04
# Epoch 393/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8658e-04
# Epoch 394/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8118e-04
# Epoch 395/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8679e-04
# Epoch 396/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7971e-04
# Epoch 397/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0020e-04
# Epoch 398/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8890e-04
# Epoch 399/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8002e-04
# Epoch 400/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.6125e-04
# Epoch 401/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0657e-04
# Epoch 402/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.4007e-04
# Epoch 403/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8740e-04
# Epoch 404/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7460e-04
# Epoch 405/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8375e-04
# Epoch 406/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8297e-04
# Epoch 407/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0415e-04
# Epoch 408/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1707e-04
# Epoch 409/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9767e-04
# Epoch 410/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9760e-04
# Epoch 411/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7937e-04
# Epoch 412/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0434e-04
# Epoch 413/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8550e-04
# Epoch 414/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7503e-04
# Epoch 415/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8772e-04
# Epoch 416/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0210e-04
# Epoch 417/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.2274e-04
# Epoch 418/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.8076e-04
# Epoch 419/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8846e-04
# Epoch 420/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8349e-04
# Epoch 421/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9447e-04
# Epoch 422/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.8569e-04
# Epoch 423/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7867e-04
# Epoch 424/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0451e-04
# Epoch 425/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.3225e-04
# Epoch 426/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0839e-04
# Epoch 427/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.3378e-04
# Epoch 428/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8646e-04
# Epoch 429/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7715e-04
# Epoch 430/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7216e-04
# Epoch 431/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.9689e-04
# Epoch 432/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8096e-04
# Epoch 433/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8477e-04
# Epoch 434/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9113e-04
# Epoch 435/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8741e-04
# Epoch 436/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9415e-04
# Epoch 437/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.3651e-04
# Epoch 438/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8049e-04
# Epoch 439/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9110e-04
# Epoch 440/500
# 16/16 - 0s - loss: 0.0016 - val_loss: 5.9359e-04
# Epoch 441/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.7757e-04
# Epoch 442/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8578e-04
# Epoch 443/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9876e-04
# Epoch 444/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0662e-04
# Epoch 445/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0228e-04
# Epoch 446/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9309e-04
# Epoch 447/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8886e-04
# Epoch 448/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8102e-04
# Epoch 449/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7945e-04
# Epoch 450/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8555e-04
# Epoch 451/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8060e-04
# Epoch 452/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8603e-04
# Epoch 453/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7961e-04
# Epoch 454/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8764e-04
# Epoch 455/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0258e-04
# Epoch 456/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8111e-04
# Epoch 457/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7360e-04
# Epoch 458/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7725e-04
# Epoch 459/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.7674e-04
# Epoch 460/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7719e-04
# Epoch 461/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8433e-04
# Epoch 462/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.9668e-04
# Epoch 463/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9513e-04
# Epoch 464/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8438e-04
# Epoch 465/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7629e-04
# Epoch 466/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.7355e-04
# Epoch 467/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8856e-04
# Epoch 468/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1937e-04
# Epoch 469/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0308e-04
# Epoch 470/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0208e-04
# Epoch 471/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8351e-04
# Epoch 472/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8880e-04
# Epoch 473/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8193e-04
# Epoch 474/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.2194e-04
# Epoch 475/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.3605e-04
# Epoch 476/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.7626e-04
# Epoch 477/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0283e-04
# Epoch 478/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.1136e-04
# Epoch 479/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0901e-04
# Epoch 480/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8180e-04
# Epoch 481/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8120e-04
# Epoch 482/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8397e-04
# Epoch 483/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.9614e-04
# Epoch 484/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8317e-04
# Epoch 485/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0719e-04
# Epoch 486/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8593e-04
# Epoch 487/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0365e-04
# Epoch 488/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8451e-04
# Epoch 489/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 6.0865e-04
# Epoch 490/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9763e-04
# Epoch 491/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8917e-04
# Epoch 492/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.8433e-04
# Epoch 493/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9204e-04
# Epoch 494/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9298e-04
# Epoch 495/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9626e-04
# Epoch 496/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.9182e-04
# Epoch 497/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.9297e-04
# Epoch 498/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.7759e-04
# Epoch 499/500
# 16/16 - 0s - loss: 0.0015 - val_loss: 5.8153e-04
# Epoch 500/500
# 16/16 - 0s - loss: 0.0014 - val_loss: 5.9681e-04
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 64)                17920
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 18,245
# Trainable params: 18,245
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
n = 10
input_x = test_x
result = []
for i in range(n):
    y_pre = model.predict(input_x)
    result.append(y_pre)
    y_pre = y_pre.reshape(y_pre.shape[0],1,y_pre.shape[1])
    input_x = np.hstack((test_x,y_pre))[:,1:,:]

# %%
res = pd.DataFrame(columns=cols)
for i in range(len(result)):
    for j in range(len(cols)):
        res.loc[i,cols[j]] = result[i][0][j]

# %%
# print('lstm mape:',mape(y_valid, lstm_pre))

# %%
for i in range(len(cols)):
    mms = min_max_scaler[i]
    res[cols[i]] = mms.inverse_transform(res[cols[i]].values.reshape(-1, 1))
    test_last[cols[i]] = mms.inverse_transform(test_last[cols[i]].values.reshape(-1, 1))

# %%
test_last = pd.concat([test_last,res[:1]])
test_last = test_last.reset_index(drop=True)
res.index = list(range(m,m+len(res)))
res
# Out:
#           Open        High         Low       Close        Volume
# 20  789.412791  795.686795  781.640578  792.817416  1.862612e+06
# 21  785.386830  791.615654  777.721679  790.884467  1.976114e+06
# 22  781.345361  787.607389  773.523924  788.397540  2.077977e+06
# 23  777.133754  783.428434  769.158170  785.289853  2.172360e+06
# 24  772.658770  778.984317  764.527562  781.556282  2.262866e+06
# 25  767.836012  774.191735  759.543743  777.182685  2.352447e+06
# 26  762.589607  768.975653  754.127606  772.148667  2.443547e+06
# 27  756.851723  763.268824  748.208446  766.430593  2.538203e+06
# 28  750.563022  757.012616  741.724714  760.005280  2.638109e+06
# 29  743.673903  750.158037  734.625120  752.853502  2.744649e+06

# %%
for col in cols:
    plt.figure(figsize=(10,6))
    plt.plot(test_last.index,test_last[col],'g',alpha=0.7)
    plt.plot(res.index,res[col],'b',alpha=0.7)
    plt.show()
