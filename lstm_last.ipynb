# %%
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.utils import shuffle
np.random.seed(0)
import missingno as mg
import datetime
from pmdarima.arima import auto_arima
from datetime import datetime,timedelta

# %%
def mape(y, y_pred):
    return np.mean(np.abs((y_pred - y) / y)) * 100

# %%
df = pd.read_csv('Google_Stock_Price_Train.csv')
df.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
test = pd.read_csv('Google_Stock_Price_Test.csv')

# %%
cols = [i for i in df.columns if i != 'Date']
min_max_scaler = []
for col in cols:
    df[col] = df[col].apply(lambda x:str(x).replace(',',''))
    df[col]=df[col].astype(float)
    
    test[col] = test[col].apply(lambda x:str(x).replace(',',''))
    test[col]=test[col].astype(float)
    
    scaler_df = pd.DataFrame(df[col])
    mms = MinMaxScaler()
    mms.fit(scaler_df)
    df[col] = mms.transform(scaler_df)
    test[col] = mms.transform(pd.DataFrame(test[col]))
    min_max_scaler.append(mms)

# %%
data = df[cols].values
X=[]
y=[]
m=20
for i in range(len(df)-m):
    X.append(data[i:m+i,:])
    y.append(data[m+i,:])
test_last = test.iloc[:m,-5:]
test_x = test.iloc[:m,-5:].values
test_x = test_x.reshape(1,test_x.shape[0],test_x.shape[1])

# %%
ind = shuffle(list(range(len(X))))
train_ind = ind[:int(0.8*len(ind))]
vali_ind = ind[int(0.8*len(ind)):]
x_train,y_train = np.array([X[i] for i in train_ind]),np.array([y[i] for i in train_ind])
x_valid,y_valid = np.array([X[i] for i in vali_ind]),np.array([y[i] for i in vali_ind])

# %%
def lstm_predict(x_train,y_train,x_valid,y_valid):
    # reshape before input
    model = tf.keras.Sequential()
    # Adding the first LSTM layer and some Dropout regularisation
    # set units = 64 for input layer
    model.add(tf.keras.layers.LSTM(units=64,return_sequences=True,input_shape=(x_train.shape[1],x_train.shape[2])))
    # drop_out layer，to prevent overfit
    model.add(tf.keras.layers.Dropout(0.2))
    # # Adding a second LSTM layer and some Dropout regularisation
#     model.add(tf.keras.layers.LSTM(units=64,return_sequences=True,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.LSTM(units=64,activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.LSTM(units=40, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
    # # Adding a third LSTM layer and some Dropout regularisation
#     model.add(tf.keras.layers.LSTM(units=32,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.3))
    # Adding the output layer
    # last input layer，input units=1
#     model.add(tf.keras.layers.Dense(units=64,activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(units=64,activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(units=y_train.shape[1],activation='linear'))
    # Compiling the RNN, choose adam optimizer 
    adam = tf.keras.optimizers.Adam(lr=0.001)
    model.compile(optimizer=adam, loss='mean_squared_error')#tf.keras.optimizers.Adam(learning_rate=0.001)
    # Fitting the RNN to the Training set
    history = model.fit(x_train, y_train, epochs=500, batch_size=64,verbose=2,validation_data=(x_valid,y_valid))
#     model.save('model.h5')
    print(model.summary())
    import matplotlib.pyplot as plt
#     #interactive images
#     loss = history.history['loss']
#     val_loss = history.history['val_loss']
#     epochs_range = range(epoch)
#     plt.plot(epochs_range, loss, label='Train Loss')
#     plt.plot(epochs_range, val_loss, label='Test Loss')
#     plt.legend(loc='upper right')
#     plt.title('Train and Val Loss')
#     plt.show()
    # train loss and validation loss plot
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('LSTM model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.show()
    return model

# %%
model = lstm_predict(x_train,y_train,x_valid,y_valid)
# Out:
# C:\Users\admin\miniconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/500
# 16/16 - 3s - loss: 0.0967 - val_loss: 0.0266
# Epoch 2/500
# 16/16 - 0s - loss: 0.0311 - val_loss: 0.0085
# Epoch 3/500
# 16/16 - 0s - loss: 0.0199 - val_loss: 0.0063
# Epoch 4/500
# 16/16 - 0s - loss: 0.0168 - val_loss: 0.0047
# Epoch 5/500
# 16/16 - 0s - loss: 0.0141 - val_loss: 0.0033
# Epoch 6/500
# 16/16 - 0s - loss: 0.0131 - val_loss: 0.0030
# Epoch 7/500
# 16/16 - 0s - loss: 0.0124 - val_loss: 0.0036
# Epoch 8/500
# 16/16 - 0s - loss: 0.0114 - val_loss: 0.0033
# Epoch 9/500
# 16/16 - 0s - loss: 0.0108 - val_loss: 0.0028
# Epoch 10/500
# 16/16 - 0s - loss: 0.0098 - val_loss: 0.0025
# Epoch 11/500
# 16/16 - 0s - loss: 0.0101 - val_loss: 0.0024
# Epoch 12/500
# 16/16 - 0s - loss: 0.0096 - val_loss: 0.0027
# Epoch 13/500
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0038
# Epoch 14/500
# 16/16 - 0s - loss: 0.0088 - val_loss: 0.0024
# Epoch 15/500
# 16/16 - 0s - loss: 0.0090 - val_loss: 0.0034
# Epoch 16/500
# 16/16 - 0s - loss: 0.0086 - val_loss: 0.0022
# Epoch 17/500
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0027
# Epoch 18/500
# 16/16 - 0s - loss: 0.0076 - val_loss: 0.0021
# Epoch 19/500
# 16/16 - 0s - loss: 0.0074 - val_loss: 0.0024
# Epoch 20/500
# 16/16 - 0s - loss: 0.0069 - val_loss: 0.0020
# Epoch 21/500
# 16/16 - 0s - loss: 0.0074 - val_loss: 0.0026
# Epoch 22/500
# 16/16 - 0s - loss: 0.0070 - val_loss: 0.0019
# Epoch 23/500
# 16/16 - 0s - loss: 0.0069 - val_loss: 0.0032
# Epoch 24/500
# 16/16 - 0s - loss: 0.0067 - val_loss: 0.0021
# Epoch 25/500
# 16/16 - 0s - loss: 0.0063 - val_loss: 0.0019
# Epoch 26/500
# 16/16 - 0s - loss: 0.0062 - val_loss: 0.0018
# Epoch 27/500
# 16/16 - 0s - loss: 0.0060 - val_loss: 0.0020
# Epoch 28/500
# 16/16 - 0s - loss: 0.0061 - val_loss: 0.0018
# Epoch 29/500
# 16/16 - 0s - loss: 0.0057 - val_loss: 0.0030
# Epoch 30/500
# 16/16 - 0s - loss: 0.0059 - val_loss: 0.0019
# Epoch 31/500
# 16/16 - 0s - loss: 0.0057 - val_loss: 0.0017
# Epoch 32/500
# 16/16 - 0s - loss: 0.0056 - val_loss: 0.0017
# Epoch 33/500
# 16/16 - 0s - loss: 0.0056 - val_loss: 0.0021
# Epoch 34/500
# 16/16 - 0s - loss: 0.0056 - val_loss: 0.0021
# Epoch 35/500
# 16/16 - 0s - loss: 0.0056 - val_loss: 0.0017
# Epoch 36/500
# 16/16 - 0s - loss: 0.0055 - val_loss: 0.0020
# Epoch 37/500
# 16/16 - 0s - loss: 0.0054 - val_loss: 0.0017
# Epoch 38/500
# 16/16 - 0s - loss: 0.0058 - val_loss: 0.0037
# Epoch 39/500
# 16/16 - 0s - loss: 0.0056 - val_loss: 0.0018
# Epoch 40/500
# 16/16 - 0s - loss: 0.0050 - val_loss: 0.0016
# Epoch 41/500
# 16/16 - 0s - loss: 0.0051 - val_loss: 0.0017
# Epoch 42/500
# 16/16 - 0s - loss: 0.0053 - val_loss: 0.0016
# Epoch 43/500
# 16/16 - 0s - loss: 0.0050 - val_loss: 0.0016
# Epoch 44/500
# 16/16 - 0s - loss: 0.0050 - val_loss: 0.0015
# Epoch 45/500
# 16/16 - 0s - loss: 0.0047 - val_loss: 0.0015
# Epoch 46/500
# 16/16 - 0s - loss: 0.0046 - val_loss: 0.0015
# Epoch 47/500
# 16/16 - 0s - loss: 0.0049 - val_loss: 0.0015
# Epoch 48/500
# 16/16 - 0s - loss: 0.0047 - val_loss: 0.0019
# Epoch 49/500
# 16/16 - 0s - loss: 0.0046 - val_loss: 0.0016
# Epoch 50/500
# 16/16 - 0s - loss: 0.0049 - val_loss: 0.0016
# Epoch 51/500
# 16/16 - 0s - loss: 0.0048 - val_loss: 0.0014
# Epoch 52/500
# 16/16 - 0s - loss: 0.0048 - val_loss: 0.0016
# Epoch 53/500
# 16/16 - 0s - loss: 0.0045 - val_loss: 0.0014
# Epoch 54/500
# 16/16 - 0s - loss: 0.0046 - val_loss: 0.0015
# Epoch 55/500
# 16/16 - 0s - loss: 0.0045 - val_loss: 0.0015
# Epoch 56/500
# 16/16 - 0s - loss: 0.0044 - val_loss: 0.0014
# Epoch 57/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0013
# Epoch 58/500
# 16/16 - 0s - loss: 0.0044 - val_loss: 0.0013
# Epoch 59/500
# 16/16 - 0s - loss: 0.0046 - val_loss: 0.0016
# Epoch 60/500
# 16/16 - 0s - loss: 0.0041 - val_loss: 0.0013
# Epoch 61/500
# 16/16 - 0s - loss: 0.0043 - val_loss: 0.0014
# Epoch 62/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0016
# Epoch 63/500
# 16/16 - 0s - loss: 0.0041 - val_loss: 0.0012
# Epoch 64/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0017
# Epoch 65/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0014
# Epoch 66/500
# 16/16 - 0s - loss: 0.0041 - val_loss: 0.0014
# Epoch 67/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0018
# Epoch 68/500
# 16/16 - 0s - loss: 0.0043 - val_loss: 0.0012
# Epoch 69/500
# 16/16 - 0s - loss: 0.0041 - val_loss: 0.0012
# Epoch 70/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0012
# Epoch 71/500
# 16/16 - 0s - loss: 0.0041 - val_loss: 0.0016
# Epoch 72/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0013
# Epoch 73/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0013
# Epoch 74/500
# 16/16 - 0s - loss: 0.0042 - val_loss: 0.0015
# Epoch 75/500
# 16/16 - 0s - loss: 0.0041 - val_loss: 0.0013
# Epoch 76/500
# 16/16 - 0s - loss: 0.0039 - val_loss: 0.0012
# Epoch 77/500
# 16/16 - 0s - loss: 0.0039 - val_loss: 0.0012
# Epoch 78/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0013
# Epoch 79/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0012
# Epoch 80/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0020
# Epoch 81/500
# 16/16 - 0s - loss: 0.0040 - val_loss: 0.0012
# Epoch 82/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0014
# Epoch 83/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0013
# Epoch 84/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0013
# Epoch 85/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0012
# Epoch 86/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0012
# Epoch 87/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0011
# Epoch 88/500
# 16/16 - 0s - loss: 0.0039 - val_loss: 0.0013
# Epoch 89/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0011
# Epoch 90/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 91/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0012
# Epoch 92/500
# 16/16 - 0s - loss: 0.0038 - val_loss: 0.0011
# Epoch 93/500
# 16/16 - 0s - loss: 0.0039 - val_loss: 0.0012
# Epoch 94/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0011
# Epoch 95/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0011
# Epoch 96/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0011
# Epoch 97/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0012
# Epoch 98/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0011
# Epoch 99/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0011
# Epoch 100/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0014
# Epoch 101/500
# 16/16 - 0s - loss: 0.0039 - val_loss: 0.0012
# Epoch 102/500
# 16/16 - 0s - loss: 0.0037 - val_loss: 0.0011
# Epoch 103/500
# 16/16 - 0s - loss: 0.0035 - val_loss: 0.0012
# Epoch 104/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0014
# Epoch 105/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 106/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 107/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 108/500
# 16/16 - 0s - loss: 0.0036 - val_loss: 0.0012
# Epoch 109/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 9.9400e-04
# Epoch 110/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0012
# Epoch 111/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 112/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 113/500
# 16/16 - 0s - loss: 0.0035 - val_loss: 0.0012
# Epoch 114/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0011
# Epoch 115/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0011
# Epoch 116/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0010
# Epoch 117/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0011
# Epoch 118/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 9.7941e-04
# Epoch 119/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0013
# Epoch 120/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0011
# Epoch 121/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.6212e-04
# Epoch 122/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0011
# Epoch 123/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0012
# Epoch 124/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0010
# Epoch 125/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0011
# Epoch 126/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.6712e-04
# Epoch 127/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 0.0010
# Epoch 128/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.7399e-04
# Epoch 129/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 130/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0010
# Epoch 131/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 9.6950e-04
# Epoch 132/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0012
# Epoch 133/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.3717e-04
# Epoch 134/500
# 16/16 - 0s - loss: 0.0033 - val_loss: 9.5826e-04
# Epoch 135/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0011
# Epoch 136/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 0.0010
# Epoch 137/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0012
# Epoch 138/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 9.3494e-04
# Epoch 139/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.0750e-04
# Epoch 140/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.5599e-04
# Epoch 141/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 142/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.9412e-04
# Epoch 143/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 144/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 145/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 146/500
# 16/16 - 0s - loss: 0.0034 - val_loss: 0.0017
# Epoch 147/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.5217e-04
# Epoch 148/500
# 16/16 - 0s - loss: 0.0032 - val_loss: 9.4022e-04
# Epoch 149/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 0.0011
# Epoch 150/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 151/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0010
# Epoch 152/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0011
# Epoch 153/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 0.0011
# Epoch 154/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 155/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 156/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 8.9209e-04
# Epoch 157/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 158/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 0.0011
# Epoch 159/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0011
# Epoch 160/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.5836e-04
# Epoch 161/500
# 16/16 - 0s - loss: 0.0031 - val_loss: 9.9372e-04
# Epoch 162/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.2978e-04
# Epoch 163/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.8243e-04
# Epoch 164/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 0.0010
# Epoch 165/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 0.0010
# Epoch 166/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.5587e-04
# Epoch 167/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.3670e-04
# Epoch 168/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.2199e-04
# Epoch 169/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.7439e-04
# Epoch 170/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.1736e-04
# Epoch 171/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.9696e-04
# Epoch 172/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 8.7314e-04
# Epoch 173/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.8956e-04
# Epoch 174/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.1226e-04
# Epoch 175/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.8582e-04
# Epoch 176/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.0463e-04
# Epoch 177/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 8.2809e-04
# Epoch 178/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 0.0010
# Epoch 179/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.1483e-04
# Epoch 180/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7102e-04
# Epoch 181/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.4708e-04
# Epoch 182/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 0.0010
# Epoch 183/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 9.1246e-04
# Epoch 184/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.8855e-04
# Epoch 185/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.2972e-04
# Epoch 186/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.2691e-04
# Epoch 187/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 0.0012
# Epoch 188/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.7984e-04
# Epoch 189/500
# 16/16 - 0s - loss: 0.0030 - val_loss: 9.2515e-04
# Epoch 190/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7909e-04
# Epoch 191/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 0.0010
# Epoch 192/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.6634e-04
# Epoch 193/500
# 16/16 - 0s - loss: 0.0029 - val_loss: 8.9807e-04
# Epoch 194/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.5279e-04
# Epoch 195/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 0.0010
# Epoch 196/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7130e-04
# Epoch 197/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.9506e-04
# Epoch 198/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.3506e-04
# Epoch 199/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7809e-04
# Epoch 200/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.7865e-04
# Epoch 201/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.7307e-04
# Epoch 202/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.2032e-04
# Epoch 203/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.6826e-04
# Epoch 204/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.4319e-04
# Epoch 205/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7124e-04
# Epoch 206/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.0809e-04
# Epoch 207/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.2442e-04
# Epoch 208/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.5096e-04
# Epoch 209/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7886e-04
# Epoch 210/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.3605e-04
# Epoch 211/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.9107e-04
# Epoch 212/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.5126e-04
# Epoch 213/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.6649e-04
# Epoch 214/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 0.0011
# Epoch 215/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.5396e-04
# Epoch 216/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.3762e-04
# Epoch 217/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.1966e-04
# Epoch 218/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7111e-04
# Epoch 219/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.1944e-04
# Epoch 220/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.8687e-04
# Epoch 221/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.1349e-04
# Epoch 222/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 7.7792e-04
# Epoch 223/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 0.0010
# Epoch 224/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.1989e-04
# Epoch 225/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.0759e-04
# Epoch 226/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.1123e-04
# Epoch 227/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.9905e-04
# Epoch 228/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.2920e-04
# Epoch 229/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.8790e-04
# Epoch 230/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.3754e-04
# Epoch 231/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.6950e-04
# Epoch 232/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.1887e-04
# Epoch 233/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.7760e-04
# Epoch 234/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.9840e-04
# Epoch 235/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.5514e-04
# Epoch 236/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.9968e-04
# Epoch 237/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.3598e-04
# Epoch 238/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.2242e-04
# Epoch 239/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.0279e-04
# Epoch 240/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.7288e-04
# Epoch 241/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.4393e-04
# Epoch 242/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.5397e-04
# Epoch 243/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.5079e-04
# Epoch 244/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 7.9582e-04
# Epoch 245/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 8.7714e-04
# Epoch 246/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.3979e-04
# Epoch 247/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.4989e-04
# Epoch 248/500
# 16/16 - 0s - loss: 0.0028 - val_loss: 9.6790e-04
# Epoch 249/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.1344e-04
# Epoch 250/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.1714e-04
# Epoch 251/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.5051e-04
# Epoch 252/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.5931e-04
# Epoch 253/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.3099e-04
# Epoch 254/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.7755e-04
# Epoch 255/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.9867e-04
# Epoch 256/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.7545e-04
# Epoch 257/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.7147e-04
# Epoch 258/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 9.9557e-04
# Epoch 259/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.6519e-04
# Epoch 260/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 0.0010
# Epoch 261/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 7.7169e-04
# Epoch 262/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.8867e-04
# Epoch 263/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.8994e-04
# Epoch 264/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.7430e-04
# Epoch 265/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.8369e-04
# Epoch 266/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.8621e-04
# Epoch 267/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.6790e-04
# Epoch 268/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.2465e-04
# Epoch 269/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.4605e-04
# Epoch 270/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.4265e-04
# Epoch 271/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.7453e-04
# Epoch 272/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.6911e-04
# Epoch 273/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.7568e-04
# Epoch 274/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.1437e-04
# Epoch 275/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.4495e-04
# Epoch 276/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.9564e-04
# Epoch 277/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.5963e-04
# Epoch 278/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.8862e-04
# Epoch 279/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.3370e-04
# Epoch 280/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.4570e-04
# Epoch 281/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.7327e-04
# Epoch 282/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.5920e-04
# Epoch 283/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.6086e-04
# Epoch 284/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.2672e-04
# Epoch 285/500
# 16/16 - 0s - loss: 0.0027 - val_loss: 8.3890e-04
# Epoch 286/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.7266e-04
# Epoch 287/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.5613e-04
# Epoch 288/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 8.1642e-04
# Epoch 289/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.6124e-04
# Epoch 290/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.6144e-04
# Epoch 291/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.0187e-04
# Epoch 292/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.8231e-04
# Epoch 293/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.8186e-04
# Epoch 294/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 7.3632e-04
# Epoch 295/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.3768e-04
# Epoch 296/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.5031e-04
# Epoch 297/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.7104e-04
# Epoch 298/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.9740e-04
# Epoch 299/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.2800e-04
# Epoch 300/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7969e-04
# Epoch 301/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6069e-04
# Epoch 302/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.0359e-04
# Epoch 303/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.2191e-04
# Epoch 304/500
# 16/16 - 0s - loss: 0.0026 - val_loss: 9.0841e-04
# Epoch 305/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 0.0010
# Epoch 306/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.2450e-04
# Epoch 307/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.8151e-04
# Epoch 308/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5794e-04
# Epoch 309/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 6.9634e-04
# Epoch 310/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7562e-04
# Epoch 311/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.0963e-04
# Epoch 312/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.6090e-04
# Epoch 313/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.4553e-04
# Epoch 314/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6069e-04
# Epoch 315/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.1848e-04
# Epoch 316/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.9457e-04
# Epoch 317/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.7258e-04
# Epoch 318/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.6697e-04
# Epoch 319/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.1325e-04
# Epoch 320/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.7905e-04
# Epoch 321/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.4252e-04
# Epoch 322/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.2164e-04
# Epoch 323/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.3514e-04
# Epoch 324/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5996e-04
# Epoch 325/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.3604e-04
# Epoch 326/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.8698e-04
# Epoch 327/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.5710e-04
# Epoch 328/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.2683e-04
# Epoch 329/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.2302e-04
# Epoch 330/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.3272e-04
# Epoch 331/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.6791e-04
# Epoch 332/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.9628e-04
# Epoch 333/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.1336e-04
# Epoch 334/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.0614e-04
# Epoch 335/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.2228e-04
# Epoch 336/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7022e-04
# Epoch 337/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.6981e-04
# Epoch 338/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7268e-04
# Epoch 339/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9621e-04
# Epoch 340/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.9036e-04
# Epoch 341/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9161e-04
# Epoch 342/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.1880e-04
# Epoch 343/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.3439e-04
# Epoch 344/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 7.4457e-04
# Epoch 345/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.6665e-04
# Epoch 346/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.9061e-04
# Epoch 347/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.8401e-04
# Epoch 348/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.7541e-04
# Epoch 349/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 9.0194e-04
# Epoch 350/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.3506e-04
# Epoch 351/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.2222e-04
# Epoch 352/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.5730e-04
# Epoch 353/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.5744e-04
# Epoch 354/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.7460e-04
# Epoch 355/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.3186e-04
# Epoch 356/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.0280e-04
# Epoch 357/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6595e-04
# Epoch 358/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.2253e-04
# Epoch 359/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.3834e-04
# Epoch 360/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.3976e-04
# Epoch 361/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9215e-04
# Epoch 362/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.0971e-04
# Epoch 363/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.8746e-04
# Epoch 364/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.7322e-04
# Epoch 365/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.3911e-04
# Epoch 366/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.4095e-04
# Epoch 367/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.5106e-04
# Epoch 368/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.7454e-04
# Epoch 369/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5331e-04
# Epoch 370/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.2552e-04
# Epoch 371/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.1230e-04
# Epoch 372/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9187e-04
# Epoch 373/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 6.9814e-04
# Epoch 374/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.4228e-04
# Epoch 375/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 8.2193e-04
# Epoch 376/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5457e-04
# Epoch 377/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6770e-04
# Epoch 378/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.8051e-04
# Epoch 379/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5066e-04
# Epoch 380/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.0327e-04
# Epoch 381/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.2710e-04
# Epoch 382/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.3814e-04
# Epoch 383/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.0563e-04
# Epoch 384/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.1598e-04
# Epoch 385/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6923e-04
# Epoch 386/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7163e-04
# Epoch 387/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.4776e-04
# Epoch 388/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.8971e-04
# Epoch 389/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.7769e-04
# Epoch 390/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.0439e-04
# Epoch 391/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.3550e-04
# Epoch 392/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.8769e-04
# Epoch 393/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 0.0012
# Epoch 394/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.6362e-04
# Epoch 395/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5255e-04
# Epoch 396/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 6.5389e-04
# Epoch 397/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.1741e-04
# Epoch 398/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7170e-04
# Epoch 399/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.3113e-04
# Epoch 400/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.4633e-04
# Epoch 401/500
# 16/16 - 0s - loss: 0.0025 - val_loss: 8.4424e-04
# Epoch 402/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 9.1129e-04
# Epoch 403/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.3957e-04
# Epoch 404/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.1777e-04
# Epoch 405/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.0079e-04
# Epoch 406/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.2373e-04
# Epoch 407/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.1856e-04
# Epoch 408/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.2012e-04
# Epoch 409/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.0949e-04
# Epoch 410/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5080e-04
# Epoch 411/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.3669e-04
# Epoch 412/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.7559e-04
# Epoch 413/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5666e-04
# Epoch 414/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 8.1425e-04
# Epoch 415/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.5207e-04
# Epoch 416/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 9.0539e-04
# Epoch 417/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.9997e-04
# Epoch 418/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 9.4608e-04
# Epoch 419/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.8950e-04
# Epoch 420/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 6.9012e-04
# Epoch 421/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.0239e-04
# Epoch 422/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9815e-04
# Epoch 423/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.4416e-04
# Epoch 424/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.2539e-04
# Epoch 425/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.4050e-04
# Epoch 426/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9585e-04
# Epoch 427/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6693e-04
# Epoch 428/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.7977e-04
# Epoch 429/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.3484e-04
# Epoch 430/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.4224e-04
# Epoch 431/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.1740e-04
# Epoch 432/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.0603e-04
# Epoch 433/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.4424e-04
# Epoch 434/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6088e-04
# Epoch 435/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7968e-04
# Epoch 436/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.2957e-04
# Epoch 437/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.8557e-04
# Epoch 438/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7327e-04
# Epoch 439/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.9646e-04
# Epoch 440/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.8450e-04
# Epoch 441/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 9.3482e-04
# Epoch 442/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5259e-04
# Epoch 443/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.3638e-04
# Epoch 444/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.0415e-04
# Epoch 445/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.4615e-04
# Epoch 446/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6620e-04
# Epoch 447/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.3971e-04
# Epoch 448/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.0584e-04
# Epoch 449/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.2064e-04
# Epoch 450/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 7.3167e-04
# Epoch 451/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.2420e-04
# Epoch 452/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 6.9865e-04
# Epoch 453/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5882e-04
# Epoch 454/500
# 16/16 - 0s - loss: 0.0020 - val_loss: 7.7146e-04
# Epoch 455/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 8.7196e-04
# Epoch 456/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.5983e-04
# Epoch 457/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7073e-04
# Epoch 458/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.0755e-04
# Epoch 459/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.1675e-04
# Epoch 460/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.1753e-04
# Epoch 461/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.0953e-04
# Epoch 462/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5456e-04
# Epoch 463/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.9811e-04
# Epoch 464/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 6.9458e-04
# Epoch 465/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.4166e-04
# Epoch 466/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.4035e-04
# Epoch 467/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.8323e-04
# Epoch 468/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 8.2789e-04
# Epoch 469/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 9.3413e-04
# Epoch 470/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.2774e-04
# Epoch 471/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 6.8945e-04
# Epoch 472/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.5272e-04
# Epoch 473/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 6.8134e-04
# Epoch 474/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.8526e-04
# Epoch 475/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.5586e-04
# Epoch 476/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 9.0038e-04
# Epoch 477/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.4748e-04
# Epoch 478/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.4219e-04
# Epoch 479/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.4763e-04
# Epoch 480/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.3930e-04
# Epoch 481/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 8.3117e-04
# Epoch 482/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 0.0012
# Epoch 483/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.7658e-04
# Epoch 484/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.8449e-04
# Epoch 485/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 9.5463e-04
# Epoch 486/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.0624e-04
# Epoch 487/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 6.9600e-04
# Epoch 488/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.2465e-04
# Epoch 489/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.0849e-04
# Epoch 490/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.9457e-04
# Epoch 491/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.0843e-04
# Epoch 492/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.6676e-04
# Epoch 493/500
# 16/16 - 0s - loss: 0.0024 - val_loss: 9.0749e-04
# Epoch 494/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.9170e-04
# Epoch 495/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 7.8493e-04
# Epoch 496/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 8.7460e-04
# Epoch 497/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 9.4726e-04
# Epoch 498/500
# 16/16 - 0s - loss: 0.0022 - val_loss: 7.9990e-04
# Epoch 499/500
# 16/16 - 0s - loss: 0.0023 - val_loss: 8.2498e-04
# Epoch 500/500
# 16/16 - 0s - loss: 0.0021 - val_loss: 7.4629e-04
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 20, 64)            17920
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 20, 64)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 55,429
# Trainable params: 55,429
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
n = 10
input_x = test_x
result = []
for i in range(n):
    y_pre = model.predict(input_x)
    result.append(y_pre)
    y_pre = y_pre.reshape(y_pre.shape[0],1,y_pre.shape[1])
    input_x = np.hstack((test_x,y_pre))[:,1:,:]

# %%
res = pd.DataFrame(columns=cols)
for i in range(len(result)):
    for j in range(len(cols)):
        res.loc[i,cols[j]] = result[i][0][j]

# %%
# print('lstm mape:',mape(y_valid, lstm_pre))

# %%
for i in range(len(cols)):
    mms = min_max_scaler[i]
    res[cols[i]] = mms.inverse_transform(res[cols[i]].values.reshape(-1, 1))
    test_last[cols[i]] = mms.inverse_transform(test_last[cols[i]].values.reshape(-1, 1))

# %%
test_last = pd.concat([test_last,res[:1]])
test_last = test_last.reset_index(drop=True)
res.index = list(range(m,m+len(res)))
res
# Out:
#           Open        High         Low       Close        Volume
# 20  784.183527  790.019829  777.780207  772.662661  1.563721e+06
# 21  771.872642  777.730317  765.464036  762.423330  1.637488e+06
# 22  761.231193  767.160466  754.745419  751.680819  1.734788e+06
# 23  746.755069  752.782913  739.962622  732.517461  1.885361e+06
# 24  725.874254  732.045711  718.597351  704.841847  2.089598e+06
# 25  696.601113  702.944183  688.631818  665.982995  2.336736e+06
# 26  657.743078  664.368210  649.075931  620.824505  2.638729e+06
# 27  625.857853  632.683042  617.272787  595.198023  2.766413e+06
# 28  609.297488  616.105389  601.118680  573.300580  2.678215e+06
# 29  603.493761  610.148462  595.587754  563.499695  2.552151e+06

# %%
for col in cols:
    plt.figure(figsize=(10,6))
    plt.plot(test_last.index,test_last[col],'g',alpha=0.7)
    plt.plot(res.index,res[col],'b',alpha=0.7)
    plt.show()
